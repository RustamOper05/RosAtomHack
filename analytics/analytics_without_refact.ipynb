# %%
import pandas as pd
import numpy as np
import os


main_data = pd.read_csv(r"C:\Users\sahab\Desktop\Участники anonimized.csv")
main_data.head(5)
# Out:
#      ФИО  Пол    Роль в мероприятии  \
# 0  ФИО_0    0  Участник мероприятия
# 1  ФИО_1    1  Участник мероприятия
# 2  ФИО_2    0  Участник мероприятия
# 3  ФИО_3    0  Участник мероприятия
# 4  ФИО_4    0  Участник мероприятия
#
#                               Список компетенций  \
# 0  Цифровое ПСР-Предприятие (Lean Smart Plant);
# 1                         Управление качеством;
# 2                         Сварочные технологии;
# 3                          Инженер-конструктор;
# 4                                     Геодезия;
#
#                             Должность Категория Начало трудового стажа  \
# 0  Инженер по подготовке производства   Инженер             1993-06-01
# 1                  Главный специалист       NaN             2000-08-01
# 2                  Электрогазосварщик       NaN                    NaN
# 3                 инженер-конструктор       NaN                 июл.05
# 4                     Мастер-лаборант       NaN                    NaN
#
#                                         Место работы                Профессия  \
# 0                     АО Чепецкий механический завод  Промышленная автоматика
# 1  Акционерное общество  Научно-исследовательский...                      NaN
# 2  "Филиал Акционерного общества ""Русатом Инфрас...                      NaN
# 3  "Акционерное Общество ""Машиностроительный зав...                      NaN
# 4                   ОБПОУ Курский монтажный техникум                      NaN
#
#   Дата рождения Начало трудовой деятельности в РОСАТОМ Образование  \
# 0    1975-04-14                             2001-01-25         NaN
# 1    1977-07-19                             2021-09-14         NaN
# 2           NaN                                    NaN         NaN
# 3    23.06.1986                                    NaN         NaN
# 4           NaN                                    NaN         NaN
#
#   Место образования Год оканчания Специальность
# 0               NaN           NaN           NaN
# 1               NaN           NaN           NaN
# 2               NaN           NaN           NaN
# 3               NaN           NaN           NaN
# 4               NaN           NaN           NaN

# %%
dir_path = r"C:\Users\sahab\Desktop\пизда_19_05"
files = os.listdir(dir_path)

# %%
data_list = []

for c, i in enumerate(files):
    data_list.append((pd.read_csv(dir_path + "/" + i).columns[:5], i, c))
data_list
# Out:
# [(Index(['№', 'ФИО', 'Компетенция', 'Баллы, ед.', 'Баллы, %'], dtype='object'),
#   'Аддитивные технологии.csv',
#   0),
#  (Index(['№', 'ФИО', 'Компетенция', 'Баллы, ед.', 'Баллы, %'], dtype='object'),
#   'Анатилический контроль.csv',
#   1),
#  (Index(['№', 'Название команды', 'ФИО участников', 'Компетенция', 'Баллы, ед.'], dtype='object'),
#   'Бетонные строительные работы.csv',
#   2),
#  (Index(['№', 'ФИО', 'Компетенция', 'Баллы, ед.', 'Баллы, %'], dtype='object'),
#   'Водитель спецавтомобиля.csv',
#   3),
#  (Index(['№', 'Название команды', 'ФИО участников', 'Компетенция', 'Баллы, ед.'], dtype='object'),
#   'Вывод из эксплуатации объектов использования атомной энергии.csv',
#   4),
#  (Index(['№', 'Название команды', 'ФИО участников', 'Компетенция', 'Баллы, ед.'], dtype='object'),
#   'Геодезия.csv',
#   5),
#  (Index(['№', 'ФИО', 'Компетенция', 'Баллы, ед.', 'Баллы, %'], dtype='object'),
#   'Изготовление прототипов.csv',
#   6),
#  (Index(['№', 'ФИО', 'Компетенция', 'Баллы, ед.', 'Баллы, %'], dtype='object'),
#   'Инженер-конструктор.csv',
#   7),
#  (Index(['№', 'ФИО', 'Компетенция', 'Баллы, ед.', 'Баллы, %'], dtype='object'),
#   'Инженер-технолог машиностроения.csv',
#   8),
#  (Index(['№', 'Название команды', 'ФИО участников', 'Компетенция', 'Баллы, ед.'], dtype='object'),
#   'Инженерное мышление. Каракури.csv',
#   9),
#  (Index(['№', 'Название команды', 'ФИО участников', 'Компетенция', 'Unnamed: 4'], dtype='object'),
#   'Инженерное проектирование.csv',
#   10),
#  (Index(['№', 'Название команды', 'ФИО участников', 'Компетенция', 'Баллы, ед.'], dtype='object'),
#   'Информационная безопасность.csv',
#   11),
#  (Index(['№', 'ФИО', 'Компетенция', 'Баллы, ед.', 'Баллы, %'], dtype='object'),
#   'Квантовые технологии.csv',
#   12),
#  (Index(['№', 'Название команды', 'ФИО участников', 'Компетенция', 'Баллы, ед.'], dtype='object'),
#   'Корпоративная защита от внутренних угроз информационной безопасности.csv',
#   13),
#  (Index(['№', 'ФИО', 'Компетенция', 'Баллы, ед.', 'Баллы, %'], dtype='object'),
#   'Машинное обучение и большие данные.csv',
#   14),
#  (Index(['№', 'Название команды', 'ФИО участников', 'Компетенция', 'Баллы, ед.'], dtype='object'),
#   'Мехатроника.csv',
#   15),
#  (Index(['№', 'ФИО', 'Компетенция', 'Баллы, ед.', 'Баллы, %'], dtype='object'),
#   'Неразрущающий контроль.csv',
#   16),
#  (Index(['№', 'ФИО', 'Компетенция', 'Баллы, ед.', 'Баллы, %'], dtype='object'),
#   'Обслуживание и ремонт оборудования релейной защиты и автоматики.csv',
#   17),
#  (Index(['№', 'ФИО', 'Компетенция', 'Баллы, ед.', 'Баллы, %'], dtype='object'),
#   'Охрана окружающей среды.csv',
#   18),
#  (Index(['№', 'ФИО', 'Компетенция', 'Баллы, ед.', 'Баллы, %'], dtype='object'),
#   'Охрана труда.csv',
#   19),
#  (Index(['№', 'Название команды', 'ФИО участников', 'Компетенция', 'Баллы, ед.'], dtype='object'),
#   'Программные решения для бизнеса.csv',
#   20),
#  (Index(['№', 'ФИО', 'Компетенция', 'Баллы, ед.', 'Баллы, %'], dtype='object'),
#   'Промышленная автоматика.csv',
#   21),
#  (Index(['№', 'Название команды', 'ФИО участников', 'Компетенция', 'Баллы, ед.'], dtype='object'),
#   'Промышленная механика и монтаж.csv',
#   22),
#  (Index(['№', 'ФИО', 'Компетенция', 'Компатриоты', 'Баллы, ед.'], dtype='object'),
#   'Работы на токарных универсальных станках.csv',
#   23),
#  (Index(['№', 'ФИО', 'Компетенция', 'Баллы, ед.', 'Баллы, %'], dtype='object'),
#   'Работы на фрезерных универсальных станках.csv',
#   24),
#  (Index(['№', 'ФИО', 'Компетенция', 'Баллы, ед.', 'Баллы, %'], dtype='object'),
#   'Радиационный контроль.csv',
#   25),
#  (Index(['№', 'ФИО', 'Компетенция', 'Баллы, ед.', 'Баллы, %'], dtype='object'),
#   'Сварочные технологии.csv',
#   26),
#  (Index(['№', 'Название команды', 'ФИО участников', 'Компетенция', 'Баллы, ед.'], dtype='object'),
#   'Сетевое и системное администрирование.csv',
#   27),
#  (Index(['№', 'ФИО', 'Компетенция', 'Баллы, ед.', 'Баллы, %'], dtype='object'),
#   'Сметное дело.csv',
#   28),
#  (Index(['№', 'Название команды', 'ФИО участников', 'Компетенция', 'Баллы, ед.'], dtype='object'),
#   'Строительный контроль.csv',
#   29),
#  (Index(['№', 'Название команды', 'ФИО участников', 'Компетенция', 'Баллы, ед.'], dtype='object'),
#   'Технологии композитов.csv',
#   30),
#  (Index(['№', 'ФИО', 'Компетенция', 'Баллы, ед.', 'Баллы, %'], dtype='object'),
#   'Технологические системы энергетических объектов.csv',
#   31),
#  (Index(['№', 'ФИО', 'Компетенция', 'Баллы, ед.', 'Баллы, %'], dtype='object'),
#   'Токарные работы на станках с ЧПУ.csv',
#   32),
#  (Index(['№', 'Название команды', 'ФИО участников', 'Компетенция', 'Баллы, ед.'], dtype='object'),
#   'Управление жизненным циклом.csv',
#   33),
#  (Index(['№', 'Название команды', 'ФИО участников', 'Компетенция', 'Баллы, ед.'], dtype='object'),
#   'Управление качеством.csv',
#   34),
#  (Index(['№', 'ФИО', 'Компетенция', 'Баллы, ед.', 'Баллы, %'], dtype='object'),
#   'Фрезерные работы на станках с ЧПУ.csv',
#   35),
#  (Index(['№', 'Название команды', 'ФИО участников', 'Компетенция', 'Баллы, ед.'], dtype='object'),
#   'Цифровое ПСР-Предприятие (Lean Smart Plant).csv',
#   36),
#  (Index(['№', 'ФИО', 'Компетенция', 'Баллы, ед.', 'Баллы, %'], dtype='object'),
#   'Электромонтаж.csv',
#   37),
#  (Index(['№', 'ФИО', 'Компетенция', 'Баллы, ед.', 'Баллы, %'], dtype='object'),
#   'Электроника.csv',
#   38)]

# %%
# display(*data_list)

# %%
huevie_ind = []
for i in data_list:
    if 'Название команды' in i[0][1]:
        huevie_ind.append(i[2])
huevie_ind
# Out:
# [2, 4, 5, 9, 10, 11, 13, 15, 20, 22, 27, 29, 30, 33, 34, 36]

# %%
data_df_list = []

for c, i in enumerate(files):
    data_df_list.append((pd.read_csv(dir_path + "/" + i), i, c))


huevie_data = []
for i in huevie_ind:
    huevie_data.append(data_df_list[i])

# %%
# display(*huevie_data)

# %%
# huevie_data[10][0]

# %%
# huevie_data

# %%
new_ne_huevie_data = []

for i in huevie_data:
    data_to_merge_copy = i[0].copy()
#     print(data_to_merge_copy)
    data_to_merge_copy["count_users"] = [
    len(i) for i in data_to_merge_copy["ФИО участников"].str.split(";")\
    .to_numpy()\
    .tolist()
    ]
    records = data_to_merge_copy.to_dict(orient='records')
    
    new_records = []
    for rec in records:
        users_names = rec['ФИО участников'].split(";")
        for c in range(rec["count_users"]):
            new_dict = rec.copy()
            new_dict["ФИО"] = users_names[c]
            new_records.append(new_dict)
    new_dataframe = pd.DataFrame.from_records(new_records)
    new_ne_huevie_data.append(new_dataframe)
#     new_ne_huevie_data.append(pd.DataFrame(new_records))

# %%
names_set = set()
lists_of_sets = []
for i in new_ne_huevie_data:
    lists_of_sets.append(set(i.columns))
u = set.intersection(*lists_of_sets)
# u

# %%
ne_huevie_ind = []
for i in data_list:
    if 'Название команды' not in i[0][1]:
        ne_huevie_ind.append(i[2])
# ne_huevie_ind
data_df_list = []

for c, i in enumerate(files):
    data_df_list.append((pd.read_csv(dir_path + "/" + i), i, c))

ne_huevie_data = []
for i in ne_huevie_ind:
    ne_huevie_data.append(data_df_list[i][0])

# %%
# new_ne_huevie_data

# %%
# ne_huevie_data

# %%
cols = [
    'ФИО',
    'Компетенция',
    'Баллы, ед.',
    'Баллы, %',
#     'Баллы по ключевым навыкам',
#     'Максимальное значение',
#     'Результат'
]

# %%
full_data = ne_huevie_data + new_ne_huevie_data

# %%
new_full_data = []
for i in full_data:
    new_data_batch = i[cols]
    new_full_data.append(new_data_batch)

# %%
# new_full_data

# %%
# display(*new_full_data)

# %%
concated_full_competition_data = pd.concat([*new_full_data], ignore_index=True)

# %%
merged_data = pd.merge(main_data, concated_full_competition_data, on='ФИО', how='inner')
# merged_data

# %%
merged_data.to_csv(r"C:\Users\sahab\Desktop\пизда_19_05_ответ\merged_data.csv")

# %%
merged_data_to_vis_cols = ['Пол', 'Роль в мероприятии', 'Должность',
       'Категория', 'Место работы', 'Профессия', 'Специальность',
       'Компетенция', 'Баллы, ед.', 'Баллы, %']

# %%
merged_data
# Out:
#          ФИО  Пол    Роль в мероприятии  \
# 0      ФИО_0    0  Участник мероприятия
# 1      ФИО_1    1  Участник мероприятия
# 2      ФИО_2    0  Участник мероприятия
# 3      ФИО_3    0  Участник мероприятия
# 4      ФИО_4    0  Участник мероприятия
# ..       ...  ...                   ...
# 443  ФИО_706    1  Участник мероприятия
# 444  ФИО_707    0  Участник мероприятия
# 445  ФИО_710    1  Участник мероприятия
# 446  ФИО_711    0  Участник мероприятия
# 447  ФИО_712    0  Участник мероприятия
#
#                                 Список компетенций  \
# 0    Цифровое ПСР-Предприятие (Lean Smart Plant);
# 1                           Управление качеством;
# 2                           Сварочные технологии;
# 3                            Инженер-конструктор;
# 4                                       Геодезия;
# ..                                             ...
# 443                         Квантовые технологии;
# 444                       Неразрушающий контроль;
# 445                       Аналитический контроль;
# 446             Токарные работы на станках с ЧПУ;
# 447                      Изготовление прототипов;
#
#                               Должность                           Категория  \
# 0    Инженер по подготовке производства                             Инженер
# 1                    Главный специалист                                 NaN
# 2                    Электрогазосварщик                                 NaN
# 3                   инженер-конструктор                                 NaN
# 4                       Мастер-лаборант                                 NaN
# ..                                  ...                                 ...
# 443                                 NaN                                 NaN
# 444                      Дефектоскопист  Специалист (рабочие специальности)
# 445        Лаборант химического анализа                                 NaN
# 446                              токарь                                 NaN
# 447                                 NaN                                 NaN
#
#     Начало трудового стажа                                       Место работы  \
# 0               1993-06-01                     АО Чепецкий механический завод
# 1               2000-08-01  Акционерное общество  Научно-исследовательский...
# 2                      NaN  "Филиал Акционерного общества ""Русатом Инфрас...
# 3                   июл.05  "Акционерное Общество ""Машиностроительный зав...
# 4                      NaN                   ОБПОУ Курский монтажный техникум
# ..                     ...                                                ...
# 443                    NaN  Национальный Исследовательский Томский Государ...
# 444             2018-08-03                             Управление предприятия
# 445             2016-10-10   Центральная научно-исследовательская лаборатория
# 446                    NaN  "АО ""Опытное Конструкторское Бюро Машинострое...
# 447                    NaN  Технологический Институт Национальный Исследов...
#
#                    Профессия Дата рождения  \
# 0    Промышленная автоматика    1975-04-14
# 1                        NaN    1977-07-19
# 2                        NaN           NaN
# 3                        NaN    23.06.1986
# 4                        NaN           NaN
# ..                       ...           ...
# 443                      NaN    2001-08-23
# 444   Неразрушающий контроль    1984-08-03
# 445                      NaN    1993-02-01
# 446                      NaN           NaN
# 447                      NaN    1999-02-18
#
#     Начало трудовой деятельности в РОСАТОМ Образование Место образования  \
# 0                               2001-01-25         NaN               NaN
# 1                               2021-09-14         NaN               NaN
# 2                                      NaN         NaN               NaN
# 3                                      NaN         NaN               NaN
# 4                                      NaN         NaN               NaN
# ..                                     ...         ...               ...
# 443                                    NaN         NaN               NaN
# 444                             2004-04-27         NaN               NaN
# 445                             2021-05-14      Высшее            ИрГУПС
# 446                                    NaN         NaN               NaN
# 447                                    NaN         NaN               NaN
#
#     Год оканчания                Специальность  \
# 0             NaN                          NaN
# 1             NaN                          NaN
# 2             NaN                          NaN
# 3             NaN                          NaN
# 4             NaN                          NaN
# ..            ...                          ...
# 443           NaN                          NaN
# 444           NaN                          NaN
# 445          2016  Эксплуатация железных дорог
# 446           NaN                          NaN
# 447           NaN                          NaN
#
#                                      Компетенция Баллы, ед. Баллы, %
# 0    Цифровое ПСР-Предприятие (Lean Smart Plant)        106     63,9
# 1                           Управление качеством        100    19,18
# 2                           Сварочные технологии        100    13,78
# 3                            Инженер-конструктор        100    38,48
# 4                                       Геодезия        100       48
# ..                                           ...        ...      ...
# 443                         Квантовые технологии         72     40,5
# 444                       Неразрушающий контроль        100     54,1
# 445                       Аналитический контроль        100    50,09
# 446             Токарные работы на станках с ЧПУ        100    56,56
# 447                      Изготовление прототипов        100    25,43
#
# [448 rows x 18 columns]

# %%
merged_to_vis = merged_data[merged_data_to_vis_cols]

# %%
cols_to_enc = ['Пол', 'Роль в мероприятии', 'Должность',
       'Категория', 'Место работы', 'Профессия', 'Специальность',
       'Компетенция']

# %%
from sklearn.preprocessing import LabelEncoder


merged_to_vis['Баллы, ед.'] = merged_to_vis['Баллы, ед.'].apply(lambda x: float(str(x).replace(',', '.')))
merged_to_vis['Баллы, %'] = merged_to_vis['Баллы, %'].apply(lambda x: float(str(x).replace(',', '.').replace('%', '')))
merged_to_vis_label_na = merged_to_vis[cols_to_enc].apply(lambda series: pd.Series(
    LabelEncoder().fit_transform(series[series.notnull()]),
    index=series[series.notnull()].index
))

merged_to_vis_label_na['Баллы, ед.'] = merged_to_vis['Баллы, ед.']
merged_to_vis_label_na['Баллы, %'] = merged_to_vis['Баллы, %']
merged_to_vis_label_na['Баллы, %'] = merged_to_vis_label_na['Баллы, %'].fillna(merged_to_vis_label_na['Баллы, %'].median())
merged_to_vis_label_na['Баллы, ед.'] = merged_to_vis_label_na['Баллы, ед.'].fillna(merged_to_vis_label_na['Баллы, ед.'].median())
# Out:
# C:\Users\sahab\AppData\Local\Temp\ipykernel_44412\1122221978.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_to_vis['Баллы, ед.'] = merged_to_vis['Баллы, ед.'].apply(lambda x: float(str(x).replace(',', '.')))
# C:\Users\sahab\AppData\Local\Temp\ipykernel_44412\1122221978.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_to_vis['Баллы, %'] = merged_to_vis['Баллы, %'].apply(lambda x: float(str(x).replace(',', '.').replace('%', '')))

# %%
merged_to_vis_label_na
# Out:
#      Пол  Роль в мероприятии  Должность  Категория  Место работы  Профессия  \
# 0      0                   0       70.0        0.0         146.0       14.0
# 1      1                   0       34.0        NaN         151.0        NaN
# 2      0                   0      195.0        NaN          92.0        NaN
# 3      0                   0      237.0        NaN          37.0        NaN
# 4      0                   0      127.0        NaN         221.0        NaN
# ..   ...                 ...        ...        ...           ...        ...
# 443    1                   0        NaN        NaN         212.0        NaN
# 444    0                   0       41.0        3.0         277.0       10.0
# 445    1                   0      116.0        NaN         343.0        NaN
# 446    0                   0      258.0        NaN          21.0        NaN
# 447    0                   0        NaN        NaN         268.0        NaN
#
#      Специальность  Компетенция  Баллы, ед.  Баллы, %
# 0              NaN           36       106.0     63.90
# 1              NaN           34       100.0     19.18
# 2              NaN           26       100.0     13.78
# 3              NaN            7       100.0     38.48
# 4              NaN            5       100.0     48.00
# ..             ...          ...         ...       ...
# 443            NaN           12        72.0     40.50
# 444            NaN           16       100.0     54.10
# 445           59.0            1       100.0     50.09
# 446            NaN           32       100.0     56.56
# 447            NaN            6       100.0     25.43
#
# [448 rows x 10 columns]

# %%
from sklearn.impute import KNNImputer


imputer = KNNImputer(n_neighbors=1)
imputed_merged_to_vis_label_na = imputer.fit_transform(merged_to_vis_label_na)
# imputed_merged_to_vis_label_na_df[9] = merged_to_vis['Баллы, %']
# imputed_merged_to_vis_label_na_df[10] = merged_to_vis['Баллы, ед.']
# imputed_merged_to_vis_label_na_df[10] = imputed_merged_to_vis_label_na_df[10].apply(lambda x: float(str(x).replace(',', '.')))
# imputed_merged_to_vis_label_na_df[9] = imputed_merged_to_vis_label_na_df[9].apply(lambda x: float(str(x).replace(',', '.').replace('%', '')))
imputed_merged_to_vis_label_na_df = pd.DataFrame(imputed_merged_to_vis_label_na)

# %%
imputed_merged_to_vis_label_na_df.columns = merged_data_to_vis_cols

# %%
imputed_merged_to_vis_label_na_df
# Out:
#      Пол  Роль в мероприятии  Должность  Категория  Место работы  Профессия  \
# 0    0.0                 0.0       70.0        0.0         146.0       14.0
# 1    1.0                 0.0       34.0        3.0         151.0       16.0
# 2    0.0                 0.0      195.0        4.0          92.0       22.0
# 3    0.0                 0.0      237.0        3.0          37.0       15.0
# 4    0.0                 0.0      127.0        3.0         221.0        0.0
# ..   ...                 ...        ...        ...           ...        ...
# 443  1.0                 0.0      179.0        0.0         212.0        4.0
# 444  0.0                 0.0       41.0        3.0         277.0       10.0
# 445  1.0                 0.0      116.0        3.0         343.0        2.0
# 446  0.0                 0.0      258.0        3.0          21.0       15.0
# 447  0.0                 0.0        0.0        4.0         268.0        4.0
#
#      Специальность  Компетенция  Баллы, ед.  Баллы, %
# 0             22.0         36.0       106.0     63.90
# 1             22.0         34.0       100.0     19.18
# 2             46.0         26.0       100.0     13.78
# 3             71.0          7.0       100.0     38.48
# 4             56.0          5.0       100.0     48.00
# ..             ...          ...         ...       ...
# 443           30.0         12.0        72.0     40.50
# 444           38.0         16.0       100.0     54.10
# 445           59.0          1.0       100.0     50.09
# 446           20.0         32.0       100.0     56.56
# 447           56.0          6.0       100.0     25.43
#
# [448 rows x 10 columns]

# %%
# from sklearn import preprocessing

# merged_to_vis = merged_to_vis.fillna('0')
# merged_to_vis["role"] = preprocessing.LabelEncoder().fit_transform(merged_to_vis["Роль в мероприятии"])
# merged_to_vis["cometentions"] = preprocessing.LabelEncoder().fit_transform(merged_to_vis["Список компетенций"])
# merged_to_vis["job"] = preprocessing.LabelEncoder().fit_transform(merged_to_vis["Должность"])
# merged_to_vis["cat"] = preprocessing.LabelEncoder().fit_transform(merged_to_vis["Категория"])
# merged_to_vis["job_name"] = preprocessing.LabelEncoder().fit_transform(merged_to_vis["Место работы"])
# merged_to_vis["proff"] = preprocessing.LabelEncoder().fit_transform(merged_to_vis["Профессия"])
# merged_to_vis["spec"] = preprocessing.LabelEncoder().fit_transform(merged_to_vis["Специальность"])
# merged_to_vis["cometentions_competition"] = preprocessing.LabelEncoder().fit_transform(merged_to_vis["Компетенция"])

# %%
# cols_nums = [
#     'Баллы, ед.', 'Баллы, %', 'role', 'cometentions', 'job',
#     'cat', 'job_name', 'proff', 'spec', 'cometentions_competition',
#     'Пол'
# ]

# %%
# merged_to_vis_coded = merged_to_vis[cols_nums]
# merged_to_vis_coded

# %%
imputed_merged_to_vis_label_na_df
# Out:
#      Пол  Роль в мероприятии  Должность  Категория  Место работы  Профессия  \
# 0    0.0                 0.0       70.0        0.0         146.0       14.0
# 1    1.0                 0.0       34.0        3.0         151.0       16.0
# 2    0.0                 0.0      195.0        4.0          92.0       22.0
# 3    0.0                 0.0      237.0        3.0          37.0       15.0
# 4    0.0                 0.0      127.0        3.0         221.0        0.0
# ..   ...                 ...        ...        ...           ...        ...
# 443  1.0                 0.0      179.0        0.0         212.0        4.0
# 444  0.0                 0.0       41.0        3.0         277.0       10.0
# 445  1.0                 0.0      116.0        3.0         343.0        2.0
# 446  0.0                 0.0      258.0        3.0          21.0       15.0
# 447  0.0                 0.0        0.0        4.0         268.0        4.0
#
#      Специальность  Компетенция  Баллы, ед.  Баллы, %
# 0             22.0         36.0       106.0     63.90
# 1             22.0         34.0       100.0     19.18
# 2             46.0         26.0       100.0     13.78
# 3             71.0          7.0       100.0     38.48
# 4             56.0          5.0       100.0     48.00
# ..             ...          ...         ...       ...
# 443           30.0         12.0        72.0     40.50
# 444           38.0         16.0       100.0     54.10
# 445           59.0          1.0       100.0     50.09
# 446           20.0         32.0       100.0     56.56
# 447           56.0          6.0       100.0     25.43
#
# [448 rows x 10 columns]

# %%
# import pandas as pd

# merged_to_vis_coded['Баллы, ед.'] = merged_to_vis_coded['Баллы, ед.'].apply(lambda x: float(str(x).replace(',', '.')))
# merged_to_vis_coded['Баллы, %'] = merged_to_vis_coded['Баллы, %'].apply(lambda x: float(str(x).replace(',', '.').replace('%', '')))

# print(merged_to_vis_coded)

# %%
from sklearn.preprocessing import StandardScaler


imputed_merged_to_vis_label_na_df.columns = merged_data_to_vis_cols
imputed_merged_to_vis_label_na_df = imputed_merged_to_vis_label_na_df
imputed_merged_to_vis_label_na_df = imputed_merged_to_vis_label_na_df.drop(columns=['Роль в мероприятии', 'Должность', 'Профессия', 'Специальность', 'Баллы, %'])
scaler = StandardScaler()
merged_to_vis_coded_scaled = pd.DataFrame(scaler.fit_transform(imputed_merged_to_vis_label_na_df))
merged_to_vis_coded_scaled.columns = imputed_merged_to_vis_label_na_df.columns

# %%
merged_to_vis_coded_scaled.columns
# Out:
# Index(['Пол', 'Категория', 'Место работы', 'Компетенция', 'Баллы, ед.'], dtype='object')

# %%
merged_data
# Out:
#          ФИО  Пол    Роль в мероприятии  \
# 0      ФИО_0    0  Участник мероприятия
# 1      ФИО_1    1  Участник мероприятия
# 2      ФИО_2    0  Участник мероприятия
# 3      ФИО_3    0  Участник мероприятия
# 4      ФИО_4    0  Участник мероприятия
# ..       ...  ...                   ...
# 443  ФИО_706    1  Участник мероприятия
# 444  ФИО_707    0  Участник мероприятия
# 445  ФИО_710    1  Участник мероприятия
# 446  ФИО_711    0  Участник мероприятия
# 447  ФИО_712    0  Участник мероприятия
#
#                                 Список компетенций  \
# 0    Цифровое ПСР-Предприятие (Lean Smart Plant);
# 1                           Управление качеством;
# 2                           Сварочные технологии;
# 3                            Инженер-конструктор;
# 4                                       Геодезия;
# ..                                             ...
# 443                         Квантовые технологии;
# 444                       Неразрушающий контроль;
# 445                       Аналитический контроль;
# 446             Токарные работы на станках с ЧПУ;
# 447                      Изготовление прототипов;
#
#                               Должность                           Категория  \
# 0    Инженер по подготовке производства                             Инженер
# 1                    Главный специалист                                 NaN
# 2                    Электрогазосварщик                                 NaN
# 3                   инженер-конструктор                                 NaN
# 4                       Мастер-лаборант                                 NaN
# ..                                  ...                                 ...
# 443                                 NaN                                 NaN
# 444                      Дефектоскопист  Специалист (рабочие специальности)
# 445        Лаборант химического анализа                                 NaN
# 446                              токарь                                 NaN
# 447                                 NaN                                 NaN
#
#     Начало трудового стажа                                       Место работы  \
# 0               1993-06-01                     АО Чепецкий механический завод
# 1               2000-08-01  Акционерное общество  Научно-исследовательский...
# 2                      NaN  "Филиал Акционерного общества ""Русатом Инфрас...
# 3                   июл.05  "Акционерное Общество ""Машиностроительный зав...
# 4                      NaN                   ОБПОУ Курский монтажный техникум
# ..                     ...                                                ...
# 443                    NaN  Национальный Исследовательский Томский Государ...
# 444             2018-08-03                             Управление предприятия
# 445             2016-10-10   Центральная научно-исследовательская лаборатория
# 446                    NaN  "АО ""Опытное Конструкторское Бюро Машинострое...
# 447                    NaN  Технологический Институт Национальный Исследов...
#
#                    Профессия Дата рождения  \
# 0    Промышленная автоматика    1975-04-14
# 1                        NaN    1977-07-19
# 2                        NaN           NaN
# 3                        NaN    23.06.1986
# 4                        NaN           NaN
# ..                       ...           ...
# 443                      NaN    2001-08-23
# 444   Неразрушающий контроль    1984-08-03
# 445                      NaN    1993-02-01
# 446                      NaN           NaN
# 447                      NaN    1999-02-18
#
#     Начало трудовой деятельности в РОСАТОМ Образование Место образования  \
# 0                               2001-01-25         NaN               NaN
# 1                               2021-09-14         NaN               NaN
# 2                                      NaN         NaN               NaN
# 3                                      NaN         NaN               NaN
# 4                                      NaN         NaN               NaN
# ..                                     ...         ...               ...
# 443                                    NaN         NaN               NaN
# 444                             2004-04-27         NaN               NaN
# 445                             2021-05-14      Высшее            ИрГУПС
# 446                                    NaN         NaN               NaN
# 447                                    NaN         NaN               NaN
#
#     Год оканчания                Специальность  \
# 0             NaN                          NaN
# 1             NaN                          NaN
# 2             NaN                          NaN
# 3             NaN                          NaN
# 4             NaN                          NaN
# ..            ...                          ...
# 443           NaN                          NaN
# 444           NaN                          NaN
# 445          2016  Эксплуатация железных дорог
# 446           NaN                          NaN
# 447           NaN                          NaN
#
#                                      Компетенция Баллы, ед. Баллы, %
# 0    Цифровое ПСР-Предприятие (Lean Smart Plant)        106     63,9
# 1                           Управление качеством        100    19,18
# 2                           Сварочные технологии        100    13,78
# 3                            Инженер-конструктор        100    38,48
# 4                                       Геодезия        100       48
# ..                                           ...        ...      ...
# 443                         Квантовые технологии         72     40,5
# 444                       Неразрушающий контроль        100     54,1
# 445                       Аналитический контроль        100    50,09
# 446             Токарные работы на станках с ЧПУ        100    56,56
# 447                      Изготовление прототипов        100    25,43
#
# [448 rows x 18 columns]

# %%
# new_users = pd.concat([merged_to_vis_coded_scaled, merged_data[[
#     'Пол', 'Роль в мероприятии', 'Список компетенций', 'Место работы',
#     'Компетенция', 'Профессия']
# ]], ignore_index=True, axis=1)

# new_users
# Out:
#            0         1         2         3         4   5   \
# 0   -0.536056 -1.185890 -0.198545  1.491070  0.632407   0
# 1    1.865476  0.816417 -0.150662  1.312651  0.293599   1
# 2   -0.536056  1.483853 -0.715685  0.598977  0.293599   0
# 3   -0.536056  0.816417 -1.242402 -1.096000  0.293599   0
# 4   -0.536056  0.816417  0.519705 -1.274419  0.293599   0
# ..        ...       ...       ...       ...       ...  ..
# 443  1.865476 -1.185890  0.433515 -0.649954 -1.287508   1
# 444 -0.536056  0.816417  1.055999 -0.293116  0.293599   0
# 445  1.865476  0.816417  1.688059 -1.631256  0.293599   1
# 446 -0.536056  0.816417 -1.395628  1.134233  0.293599   0
# 447 -0.536056  1.483853  0.969809 -1.185209  0.293599   0
#
#                        6                                              7   \
# 0    Участник мероприятия  Цифровое ПСР-Предприятие (Lean Smart Plant);
# 1    Участник мероприятия                         Управление качеством;
# 2    Участник мероприятия                         Сварочные технологии;
# 3    Участник мероприятия                          Инженер-конструктор;
# 4    Участник мероприятия                                     Геодезия;
# ..                    ...                                            ...
# 443  Участник мероприятия                         Квантовые технологии;
# 444  Участник мероприятия                       Неразрушающий контроль;
# 445  Участник мероприятия                       Аналитический контроль;
# 446  Участник мероприятия             Токарные работы на станках с ЧПУ;
# 447  Участник мероприятия                      Изготовление прототипов;
#
#                                                     8   \
# 0                       АО Чепецкий механический завод
# 1    Акционерное общество  Научно-исследовательский...
# 2    "Филиал Акционерного общества ""Русатом Инфрас...
# 3    "Акционерное Общество ""Машиностроительный зав...
# 4                     ОБПОУ Курский монтажный техникум
# ..                                                 ...
# 443  Национальный Исследовательский Томский Государ...
# 444                             Управление предприятия
# 445   Центральная научно-исследовательская лаборатория
# 446  "АО ""Опытное Конструкторское Бюро Машинострое...
# 447  Технологический Институт Национальный Исследов...
#
#                                               9                        10
# 0    Цифровое ПСР-Предприятие (Lean Smart Plant)  Промышленная автоматика
# 1                           Управление качеством                      NaN
# 2                           Сварочные технологии                      NaN
# 3                            Инженер-конструктор                      NaN
# 4                                       Геодезия                      NaN
# ..                                           ...                      ...
# 443                         Квантовые технологии                      NaN
# 444                       Неразрушающий контроль   Неразрушающий контроль
# 445                       Аналитический контроль                      NaN
# 446             Токарные работы на станках с ЧПУ                      NaN
# 447                      Изготовление прототипов                      NaN
#
# [448 rows x 11 columns]

# %%
merged_to_vis_coded_scaled = pd.DataFrame(merged_to_vis_coded_scaled)

# %%
us_readed = pd.read_csv(r"C:\Users\sahab\Desktop\csv\user_cluster.csv", index_col='Unnamed: 0')
us_readed.head()
# Out:
#         Пол  Категория  Место работы  Компетенция  Баллы, ед.  clusters family
# 0 -0.536056  -1.185890     -0.198545     1.491070    0.632407         1  ФИО_0
# 1  1.865476   0.816417     -0.150662     1.312651    0.293599         0  ФИО_1
# 2 -0.536056   1.483853     -0.715685     0.598977    0.293599         3  ФИО_2
# 3 -0.536056   0.816417     -1.242402    -1.096000    0.293599         0  ФИО_3
# 4 -0.536056   0.816417      0.519705    -1.274419    0.293599         0  ФИО_4

# %%
us_readed_cols = us_readed.columns.to_list()
us_cols = [
    'Пол_dec', 'Роль в мероприятии_dec', 'Список компетенций_dec', 'Место работы_dec',
    'Компетенция_dec', 'Профессия_dec'
]

new_users_cols = us_readed_cols + us_cols

# %%
new_users_cols
# Out:
# ['Пол',
#  'Категория',
#  'Место работы',
#  'Компетенция',
#  'Баллы, ед.',
#  'clusters',
#  'family',
#  'Пол_dec',
#  'Роль в мероприятии_dec',
#  'Список компетенций_dec',
#  'Место работы_dec',
#  'Компетенция_dec',
#  'Профессия_dec']

# %%
new_data = pd.concat([
    us_readed, merged_data[[
    'Пол', 'Роль в мероприятии', 'Список компетенций', 'Место работы',
    'Компетенция', 'Профессия']
]], ignore_index=True, axis=1)

new_data.columns = new_users_cols

# %%
new_data.to_csv(r"C:\Users\sahab\Desktop\csv\new_us_dec_data.csv")

# %%
import seaborn as sns

sns.pairplot(merged_to_vis_coded_scaled, diag_kind="hist")

# %%
import seaborn as sns


sns.set(rc={'figure.figsize':(20,20)})
sns.set_style("whitegrid")
sns.pairplot(imputed_merged_to_vis_label_na_df, diag_kind="hist")

# %%
to_clast = merged_to_vis_coded_scaled.copy()
to_clast.cols = [i for i in range(len(to_clast.columns))]
# Out:
# C:\Users\sahab\AppData\Local\Temp\ipykernel_44412\2669488248.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   to_clast.cols = [i for i in range(len(to_clast.columns))]

# %%
cat_index = to_clast.cols[:-1]

# %%
cat_index
# Out:
# [0, 1, 2, 3]

# %%
from kmodes.kprototypes import KPrototypes
import matplotlib.pyplot as plt


def plot_elbow_curve(start, end, data):

    no_of_clusters = list(range(start, end+1))
    cost_values = []
    
    for k in no_of_clusters:
        test_model = KPrototypes(n_clusters=k, init='Huang', random_state=42)
        test_model.fit_predict(data, categorical=cat_index)
        cost_values.append(test_model.cost_)
        
    sns.set_theme(style="whitegrid", palette="bright", font_scale=1.2)
    
    plt.figure(figsize=(15, 7))
    ax = sns.lineplot(x=no_of_clusters, y=cost_values, marker="o", dashes=False)
    ax.set_title('Elbow curve', fontsize=18)
    ax.set_xlabel('No of clusters', fontsize=14)
    ax.set_ylabel('Cost', fontsize=14)
    ax.set(xlim=(start-0.1, end+0.1))
    plt.plot();
    
    
plot_elbow_curve(2, 10, merged_to_vis_coded_scaled)

# %%
from sklearn.metrics import silhouette_score
def plot_silhouette_score_curve(start, end, data):
   
    no_of_clusters = list(range(start, end+1))
    silhouette_score_values = []
    
    for k in no_of_clusters:
        test_model = KPrototypes(n_clusters=k, init='Cao', random_state=42, n_jobs=-1)
        test_model.fit_predict(data, categorical=cat_index)
        silhouette_score_values.append(silhouette_score(data, test_model.labels_))
        
    sns.set_theme(style="whitegrid", palette="bright", font_scale=1.2)
    
    plt.figure(figsize=(15, 7))
    ax = sns.lineplot(x=no_of_clusters, y=silhouette_score_values, marker="o", dashes=False)
    ax.set_title('Silhouette Score curve', fontsize=18)
    ax.set_xlabel('No of clusters', fontsize=14)
    ax.set_ylabel('Silhouette Score', fontsize=14)
    ax.set(xlim=(start-0.1, end+0.1))
    plt.plot();
    
plot_silhouette_score_curve(2,10,merged_to_vis_coded_scaled)

# %%
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster import hierarchy


clusters = hierarchy.linkage(merged_to_vis_coded_scaled, method="average")
dendrogram = hierarchy.dendrogram(clusters)

# %%
clusters = hierarchy.linkage(merged_to_vis_coded_scaled, method="ward")
dendrogram = hierarchy.dendrogram(clusters)

# %%
clusters = hierarchy.linkage(merged_to_vis_coded_scaled, method="complete")
dendrogram = hierarchy.dendrogram(clusters)

# %%
clustering_ag_av = AgglomerativeClustering(linkage="average", n_clusters=7).fit(merged_to_vis_coded_scaled)
labels_av = clustering_ag_av.labels_

clustering_ag_ward = AgglomerativeClustering(linkage="ward", n_clusters=9).fit(merged_to_vis_coded_scaled)
labels_ward = clustering_ag_ward.labels_

clustering_ag_single = AgglomerativeClustering(linkage="complete", n_clusters=9).fit(merged_to_vis_coded_scaled)
labels_single = clustering_ag_single.labels_

# %%
ier_dtataset = pd.concat([merged_to_vis_coded_scaled, pd.Series(labels_av)], ignore_index=True, axis=1)
sns.pairplot(ier_dtataset, diag_kind="hist", hue=5, palette="tab10")

# %%
ier_dtataset = pd.concat([merged_to_vis_coded_scaled, pd.Series(labels_ward)], ignore_index=True, axis=1)
sns.pairplot(ier_dtataset, diag_kind="hist", hue=5, palette="tab10")

# %%
ier_dtataset = pd.concat([merged_to_vis_coded_scaled, pd.Series(labels_single)], ignore_index=True, axis=1)
sns.pairplot(ier_dtataset, diag_kind="hist", hue=5, palette="tab10")

# %%
test_model = KPrototypes(n_clusters=7, random_state=42)
preds = test_model.fit_predict(merged_to_vis_coded_scaled, categorical=[0, 1, 2, 3])
ier_dtataset = pd.concat([merged_to_vis_coded_scaled, pd.Series(preds)], ignore_index=True, axis=1)
sns.pairplot(ier_dtataset, diag_kind="hist", hue=5, palette="tab10")

# %%
from kmodes.kmodes import KModes


kmodes = KModes(verbose=0,
                n_clusters=5, 
                random_state=42)

kmodes_clusters = kmodes.fit_predict(merged_to_vis_coded_scaled)
ier_dtataset = pd.concat([merged_to_vis_coded_scaled, pd.Series(kmodes_clusters)], ignore_index=True, axis=1)
sns.pairplot(ier_dtataset, diag_kind="hist", hue=5, palette="tab10")

# %%
kmodes = KModes(verbose=0,
                n_clusters=4, 
                random_state=42)

kmodes_clusters = kmodes.fit_predict(merged_to_vis_coded_scaled)
ier_dtataset = pd.concat([merged_to_vis_coded_scaled, pd.Series(kmodes_clusters)], ignore_index=True, axis=1)
sns.pairplot(ier_dtataset, diag_kind="hist", hue=5, palette="tab10")

# %%
merged_to_vis_coded_scaled["clusters"] = kmodes_clusters

# %%
merged_to_vis_coded_scaled["family"] = main_data["ФИО"]

# %%
merged_to_vis_coded_scaled
# Out:
#           Пол  Категория  Место работы  Компетенция  Баллы, ед.  clusters  \
# 0   -0.536056  -1.185890     -0.198545     1.491070    0.632407         1
# 1    1.865476   0.816417     -0.150662     1.312651    0.293599         0
# 2   -0.536056   1.483853     -0.715685     0.598977    0.293599         3
# 3   -0.536056   0.816417     -1.242402    -1.096000    0.293599         0
# 4   -0.536056   0.816417      0.519705    -1.274419    0.293599         0
# ..        ...        ...           ...          ...         ...       ...
# 443  1.865476  -1.185890      0.433515    -0.649954   -1.287508         1
# 444 -0.536056   0.816417      1.055999    -0.293116    0.293599         0
# 445  1.865476   0.816417      1.688059    -1.631256    0.293599         0
# 446 -0.536056   0.816417     -1.395628     1.134233    0.293599         0
# 447 -0.536056   1.483853      0.969809    -1.185209    0.293599         3
#
#       family
# 0      ФИО_0
# 1      ФИО_1
# 2      ФИО_2
# 3      ФИО_3
# 4      ФИО_4
# ..       ...
# 443  ФИО_443
# 444  ФИО_444
# 445  ФИО_445
# 446  ФИО_446
# 447  ФИО_447
#
# [448 rows x 7 columns]

# %%
merged_to_vis_coded_scaled.to_csv(r'C:\Users\sahab\Desktop\csv\user_cluster.csv')

# %%
ier_dtataset.to_csv(r'C:\Users\sahab\Desktop\csv\user_cluster.csv')

# %%
main_data
# Out:
#          ФИО  Пол    Роль в мероприятии  \
# 0      ФИО_0    0  Участник мероприятия
# 1      ФИО_1    1  Участник мероприятия
# 2      ФИО_2    0  Участник мероприятия
# 3      ФИО_3    0  Участник мероприятия
# 4      ФИО_4    0  Участник мероприятия
# ..       ...  ...                   ...
# 708  ФИО_708    0  Участник мероприятия
# 709  ФИО_709    1  Участник мероприятия
# 710  ФИО_710    1  Участник мероприятия
# 711  ФИО_711    0  Участник мероприятия
# 712  ФИО_712    0  Участник мероприятия
#
#                                 Список компетенций  \
# 0    Цифровое ПСР-Предприятие (Lean Smart Plant);
# 1                           Управление качеством;
# 2                           Сварочные технологии;
# 3                            Инженер-конструктор;
# 4                                       Геодезия;
# ..                                             ...
# 708                 Бетонные строительные работы;
# 709                         Управление качеством;
# 710                       Аналитический контроль;
# 711             Токарные работы на станках с ЧПУ;
# 712                      Изготовление прототипов;
#
#                               Должность Категория Начало трудового стажа  \
# 0    Инженер по подготовке производства   Инженер             1993-06-01
# 1                    Главный специалист       NaN             2000-08-01
# 2                    Электрогазосварщик       NaN                    NaN
# 3                   инженер-конструктор       NaN                 июл.05
# 4                       Мастер-лаборант       NaN                    NaN
# ..                                  ...       ...                    ...
# 708                            Бетонщик       NaN                    NaN
# 709                 Инженер по качеству       NaN                09.2013
# 710        Лаборант химического анализа       NaN             2016-10-10
# 711                              токарь       NaN                    NaN
# 712                                 NaN       NaN                    NaN
#
#                                           Место работы  \
# 0                       АО Чепецкий механический завод
# 1    Акционерное общество  Научно-исследовательский...
# 2    "Филиал Акционерного общества ""Русатом Инфрас...
# 3    "Акционерное Общество ""Машиностроительный зав...
# 4                     ОБПОУ Курский монтажный техникум
# ..                                                 ...
# 708                   ООО Трест Рос Спец Энерго монтаж
# 709               "ФГУП ""Приборостроительный завод"""
# 710   Центральная научно-исследовательская лаборатория
# 711  "АО ""Опытное Конструкторское Бюро Машинострое...
# 712  Технологический Институт Национальный Исследов...
#
#                    Профессия Дата рождения  \
# 0    Промышленная автоматика    1975-04-14
# 1                        NaN    1977-07-19
# 2                        NaN           NaN
# 3                        NaN    23.06.1986
# 4                        NaN           NaN
# ..                       ...           ...
# 708                      NaN           NaN
# 709                      NaN    22.06.1990
# 710                      NaN    1993-02-01
# 711                      NaN           NaN
# 712                      NaN    1999-02-18
#
#     Начало трудовой деятельности в РОСАТОМ Образование Место образования  \
# 0                               2001-01-25         NaN               NaN
# 1                               2021-09-14         NaN               NaN
# 2                                      NaN         NaN               NaN
# 3                                      NaN         NaN               NaN
# 4                                      NaN         NaN               NaN
# ..                                     ...         ...               ...
# 708                                    NaN         NaN               NaN
# 709                                    NaN         NaN               NaN
# 710                             2021-05-14      Высшее            ИрГУПС
# 711                                    NaN         NaN               NaN
# 712                                    NaN         NaN               NaN
#
#     Год оканчания                Специальность
# 0             NaN                          NaN
# 1             NaN                          NaN
# 2             NaN                          NaN
# 3             NaN                          NaN
# 4             NaN                          NaN
# ..            ...                          ...
# 708           NaN                          NaN
# 709           NaN                          NaN
# 710          2016  Эксплуатация железных дорог
# 711           NaN                          NaN
# 712           NaN                          NaN
#
# [713 rows x 15 columns]

# %%
concated_full_competition_data
# Out:
# 0      100.0
# 1      100.0
# 2      100.0
# 3      100.0
# 4      100.0
#        ...
# 707    106.0
# 708    106.0
# 709    106.0
# 710    106.0
# 711    106.0
# Name: Баллы, ед., Length: 712, dtype: float64

# %%
concated_full_competition_data['Баллы, ед.'] = concated_full_competition_data['Баллы, ед.'].apply(lambda x: float(str(x).replace(',', '.')))
concated_full_competition_data['Баллы, %'] = concated_full_competition_data['Баллы, %'].apply(lambda x: float(str(x).replace(',', '.').replace('%', '')))
concated_full_competition_data_grouped = concated_full_competition_data.groupby('Компетенция').agg({'ФИО': 'count', 'Баллы, ед.': 'mean', 'Баллы, %': 'mean'})

concated_full_competition_data_grouped["Баллы, %"] = concated_full_competition_data_grouped["Баллы, %"].fillna(concated_full_competition_data_grouped["Баллы, %"].median())

# %%
concated_full_competition_data_grouped = concated_full_competition_data_grouped.reset_index()

# %%
concated_full_competition_data_grouped
# Out:
#                                           Компетенция  ФИО  Баллы, ед.  \
# 0                               Аддитивные технологии    7  100.000000
# 1                              Аналитический контроль   20  100.000000
# 2                        Бетонные строительные работы   15  100.000000
# 3                             Водитель спецавтомобиля   15  100.000000
# 4   Вывод из эксплуатации объектов использования а...   32  100.000000
# 5                                            Геодезия   12  100.000000
# 6                             Изготовление прототипов    9  100.000000
# 7                                 Инженер-конструктор   20  100.000000
# 8                     Инженер-технолог машиностроения    9  100.000000
# 9                       Инженерное мышление. Каракури   24  100.000000
# 10                          Инженерное проектирование   47   18.286383
# 11                        Информационная безопасность   20  100.000000
# 12                               Квантовые технологии   14   72.000000
# 13  Корпоративная защита от внутренних угроз инфор...   16  100.000000
# 14                 Машинное обучение и большие данные   12  100.000000
# 15                                        Мехатроника   22  100.000000
# 16                             Неразрушающий контроль   15  100.000000
# 17  Обслуживание и ремонт оборудования релейной за...    8  100.000000
# 18                            Охрана окружающей среды   18  100.000000
# 19                                       Охрана труда   22  100.000000
# 20                    Программные решения для бизнеса   27  100.000000
# 21                            Промышленная автоматика   10  100.000000
# 22                     Промышленная механика и монтаж   20   41.286444
# 23           Работы на токарных универсальных станках    7  100.000000
# 24          Работы на фрезерных универсальных станках    7  100.000000
# 25                              Радиационный контроль   15  100.000000
# 26                               Сварочные технологии   20  100.000000
# 27              Сетевое и системное администрирование   28  100.000000
# 28                                       Сметное дело   14  100.000000
# 29                              Строительный контроль   16  100.000000
# 30                              Технологии композитов   16  100.000000
# 31    Технологические системы энергетических объектов   10  100.000000
# 32                   Токарные работы на станках с ЧПУ    8  100.000000
# 33                        Управление жизненным циклом   63   53.966667
# 34                               Управление качеством   28  100.000000
# 35                  Фрезерные работы на станках с ЧПУ    7  100.000000
# 36        Цифровое ПСР-Предприятие (Lean Smart Plant)   24  106.000000
# 37                                      Электромонтаж   16  100.000000
# 38                                        Электроника   19  100.000000
#
#      Баллы, %
# 0   52.620000
# 1   44.152000
# 2   69.104000
# 3   51.631333
# 4   67.777500
# 5   62.883333
# 6   29.062222
# 7   31.878000
# 8   51.706667
# 9   70.763750
# 10  47.405000
# 11   8.328000
# 12  27.521429
# 13  53.938750
# 14  42.183333
# 15  40.536364
# 16  53.960000
# 17  63.912500
# 18  46.901667
# 19  46.490000
# 20  44.642222
# 21  36.252000
# 22  47.405000
# 23  48.974286
# 24  44.000000
# 25  59.136667
# 26  40.381500
# 27  30.349286
# 28  47.942857
# 29  61.562500
# 30  65.276250
# 31  47.405000
# 32  54.240000
# 33  53.966667
# 34  42.038571
# 35  41.534286
# 36  58.466250
# 37  41.606875
# 38  37.719474

# %%
def us_cnt(x):
    if x < 10:
        return 1
    if x >= 10 and x < 25:
        return 2
    if x >= 25 and x < 40:
        return 3
    if x >= 40:
        return 4
    
    
concated_full_competition_data_grouped["cnt_users"] = concated_full_competition_data_grouped["ФИО"].apply(lambda x: us_cnt(x))

# %%
concated_full_competition_data_grouped
# Out:
#                                           Компетенция  ФИО  Баллы, ед.  \
# 0                               Аддитивные технологии    7  100.000000
# 1                              Аналитический контроль   20  100.000000
# 2                        Бетонные строительные работы   15  100.000000
# 3                             Водитель спецавтомобиля   15  100.000000
# 4   Вывод из эксплуатации объектов использования а...   32  100.000000
# 5                                            Геодезия   12  100.000000
# 6                             Изготовление прототипов    9  100.000000
# 7                                 Инженер-конструктор   20  100.000000
# 8                     Инженер-технолог машиностроения    9  100.000000
# 9                       Инженерное мышление. Каракури   24  100.000000
# 10                          Инженерное проектирование   47   18.286383
# 11                        Информационная безопасность   20  100.000000
# 12                               Квантовые технологии   14   72.000000
# 13  Корпоративная защита от внутренних угроз инфор...   16  100.000000
# 14                 Машинное обучение и большие данные   12  100.000000
# 15                                        Мехатроника   22  100.000000
# 16                             Неразрушающий контроль   15  100.000000
# 17  Обслуживание и ремонт оборудования релейной за...    8  100.000000
# 18                            Охрана окружающей среды   18  100.000000
# 19                                       Охрана труда   22  100.000000
# 20                    Программные решения для бизнеса   27  100.000000
# 21                            Промышленная автоматика   10  100.000000
# 22                     Промышленная механика и монтаж   20   41.286444
# 23           Работы на токарных универсальных станках    7  100.000000
# 24          Работы на фрезерных универсальных станках    7  100.000000
# 25                              Радиационный контроль   15  100.000000
# 26                               Сварочные технологии   20  100.000000
# 27              Сетевое и системное администрирование   28  100.000000
# 28                                       Сметное дело   14  100.000000
# 29                              Строительный контроль   16  100.000000
# 30                              Технологии композитов   16  100.000000
# 31    Технологические системы энергетических объектов   10  100.000000
# 32                   Токарные работы на станках с ЧПУ    8  100.000000
# 33                        Управление жизненным циклом   63   53.966667
# 34                               Управление качеством   28  100.000000
# 35                  Фрезерные работы на станках с ЧПУ    7  100.000000
# 36        Цифровое ПСР-Предприятие (Lean Smart Plant)   24  106.000000
# 37                                      Электромонтаж   16  100.000000
# 38                                        Электроника   19  100.000000
#
#      Баллы, %  cnt_users
# 0   52.620000          1
# 1   44.152000          2
# 2   69.104000          2
# 3   51.631333          2
# 4   67.777500          3
# 5   62.883333          2
# 6   29.062222          1
# 7   31.878000          2
# 8   51.706667          1
# 9   70.763750          2
# 10  47.405000          4
# 11   8.328000          2
# 12  27.521429          2
# 13  53.938750          2
# 14  42.183333          2
# 15  40.536364          2
# 16  53.960000          2
# 17  63.912500          1
# 18  46.901667          2
# 19  46.490000          2
# 20  44.642222          3
# 21  36.252000          2
# 22  47.405000          2
# 23  48.974286          1
# 24  44.000000          1
# 25  59.136667          2
# 26  40.381500          2
# 27  30.349286          3
# 28  47.942857          2
# 29  61.562500          2
# 30  65.276250          2
# 31  47.405000          2
# 32  54.240000          1
# 33  53.966667          4
# 34  42.038571          3
# 35  41.534286          1
# 36  58.466250          2
# 37  41.606875          2
# 38  37.719474          2

# %%
concated_full_competition_data_grouped.to_csv(r"C:\Users\sahab\Desktop\rijulya_ya_tebya_lublyu.csv")

# %%
concated_full_competition_data_grouped_for_train = concated_full_competition_data_grouped[["Баллы, %", "cnt_users"]]
concated_full_competition_data_grouped_for_train
# Out:
#      Баллы, %  cnt_users
# 0   52.620000          1
# 1   44.152000          2
# 2   69.104000          2
# 3   51.631333          2
# 4   67.777500          3
# 5   62.883333          2
# 6   29.062222          1
# 7   31.878000          2
# 8   51.706667          1
# 9   70.763750          2
# 10  47.405000          4
# 11   8.328000          2
# 12  27.521429          2
# 13  53.938750          2
# 14  42.183333          2
# 15  40.536364          2
# 16  53.960000          2
# 17  63.912500          1
# 18  46.901667          2
# 19  46.490000          2
# 20  44.642222          3
# 21  36.252000          2
# 22  47.405000          2
# 23  48.974286          1
# 24  44.000000          1
# 25  59.136667          2
# 26  40.381500          2
# 27  30.349286          3
# 28  47.942857          2
# 29  61.562500          2
# 30  65.276250          2
# 31  47.405000          2
# 32  54.240000          1
# 33  53.966667          4
# 34  42.038571          3
# 35  41.534286          1
# 36  58.466250          2
# 37  41.606875          2
# 38  37.719474          2

# %%
concated_full_competition_data_grouped_for_train.columns = [0, 1]

# %%
concated_full_competition_data_grouped_for_train = StandardScaler().fit_transform(concated_full_competition_data_grouped_for_train)

# %%
clustering_ag_ward = AgglomerativeClustering(linkage="average", n_clusters=5).fit(concated_full_competition_data_grouped_for_train)
labels_ward = clustering_ag_ward.labels_
ier_dtataset = pd.concat([pd.DataFrame(concated_full_competition_data_grouped_for_train), pd.Series(labels_ward)], ignore_index=True, axis=1)
ier_dtataset
sns.pairplot(ier_dtataset, diag_kind="hist", hue=2, palette="tab10")

# %%
concated_full_competition_data_grouped["Компетенция"].values
# Out:
# array(['Аддитивные технологии', 'Аналитический контроль',
#        'Бетонные строительные работы', 'Водитель спецавтомобиля',
#        'Вывод из эксплуатации объектов использования атомной энергии',
#        'Геодезия', 'Изготовление прототипов', 'Инженер-конструктор',
#        'Инженер-технолог машиностроения', 'Инженерное мышление. Каракури',
#        'Инженерное проектирование', 'Информационная безопасность',
#        'Квантовые технологии',
#        'Корпоративная защита от внутренних угроз информационной безопасности',
#        'Машинное обучение и большие данные', 'Мехатроника',
#        'Неразрушающий контроль',
#        'Обслуживание и ремонт оборудования релейной защиты и автоматики',
#        'Охрана окружающей среды', 'Охрана труда',
#        'Программные решения для бизнеса', 'Промышленная автоматика',
#        'Промышленная механика и монтаж',
#        'Работы на токарных универсальных станках',
#        'Работы на фрезерных универсальных станках',
#        'Радиационный контроль', 'Сварочные технологии',
#        'Сетевое и системное администрирование', 'Сметное дело',
#        'Строительный контроль', 'Технологии композитов',
#        'Технологические системы энергетических объектов',
#        'Токарные работы на станках с ЧПУ', 'Управление жизненным циклом',
#        'Управление качеством', 'Фрезерные работы на станках с ЧПУ',
#        'Цифровое ПСР-Предприятие (Lean Smart Plant)', 'Электромонтаж',
#        'Электроника'], dtype=object)

# %%
# Out:
#            0         1  2
# 0   0.378760 -1.396424  3
# 1  -0.291856  0.000000  0
# 2   1.684194  0.000000  2
# 3   0.300463  0.000000  0
# 4   1.579143  1.396424  2
# 5   1.191554  0.000000  2
# 6  -1.486876 -1.396424  0
# 7  -1.263883  0.000000  0
# 8   0.306429 -1.396424  3
# 9   1.815637  0.000000  2
# 10 -0.034237  2.792848  1
# 11 -3.128903  0.000000  4
# 12 -1.608898  0.000000  0
# 13  0.483197  0.000000  0
# 14 -0.447762  0.000000  0
# 15 -0.578192  0.000000  0
# 16  0.484880  0.000000  0
# 17  1.273058 -1.396424  3
# 18 -0.074098  0.000000  0
# 19 -0.106700  0.000000  0
# 20 -0.253033  1.396424  1
# 21 -0.917488  0.000000  0
# 22 -0.034237  0.000000  0
# 23  0.090041 -1.396424  3
# 24 -0.303893 -1.396424  3
# 25  0.894841  0.000000  2
# 26 -0.590457  0.000000  0
# 27 -1.384948  1.396424  1
# 28  0.008358  0.000000  0
# 29  1.086952  0.000000  2
# 30  1.381059  0.000000  2
# 31 -0.034237  0.000000  0
# 32  0.507054 -1.396424  3
# 33  0.485408  2.792848  1
# 34 -0.459226  1.396424  1
# 35 -0.499163 -1.396424  3
# 36  0.841748  0.000000  2
# 37 -0.493414  0.000000  0
# 38 -0.801273  0.000000  0

# %%
concated_full_competition_data_grouped["cluster"] = labels_ward
concated_full_competition_data_grouped
# Out:
#                                           Компетенция  ФИО  Баллы, ед.  \
# 0                               Аддитивные технологии    7  100.000000
# 1                              Аналитический контроль   20  100.000000
# 2                        Бетонные строительные работы   15  100.000000
# 3                             Водитель спецавтомобиля   15  100.000000
# 4   Вывод из эксплуатации объектов использования а...   32  100.000000
# 5                                            Геодезия   12  100.000000
# 6                             Изготовление прототипов    9  100.000000
# 7                                 Инженер-конструктор   20  100.000000
# 8                     Инженер-технолог машиностроения    9  100.000000
# 9                       Инженерное мышление. Каракури   24  100.000000
# 10                          Инженерное проектирование   47   18.286383
# 11                        Информационная безопасность   20  100.000000
# 12                               Квантовые технологии   14   72.000000
# 13  Корпоративная защита от внутренних угроз инфор...   16  100.000000
# 14                 Машинное обучение и большие данные   12  100.000000
# 15                                        Мехатроника   22  100.000000
# 16                             Неразрушающий контроль   15  100.000000
# 17  Обслуживание и ремонт оборудования релейной за...    8  100.000000
# 18                            Охрана окружающей среды   18  100.000000
# 19                                       Охрана труда   22  100.000000
# 20                    Программные решения для бизнеса   27  100.000000
# 21                            Промышленная автоматика   10  100.000000
# 22                     Промышленная механика и монтаж   20   41.286444
# 23           Работы на токарных универсальных станках    7  100.000000
# 24          Работы на фрезерных универсальных станках    7  100.000000
# 25                              Радиационный контроль   15  100.000000
# 26                               Сварочные технологии   20  100.000000
# 27              Сетевое и системное администрирование   28  100.000000
# 28                                       Сметное дело   14  100.000000
# 29                              Строительный контроль   16  100.000000
# 30                              Технологии композитов   16  100.000000
# 31    Технологические системы энергетических объектов   10  100.000000
# 32                   Токарные работы на станках с ЧПУ    8  100.000000
# 33                        Управление жизненным циклом   63   53.966667
# 34                               Управление качеством   28  100.000000
# 35                  Фрезерные работы на станках с ЧПУ    7  100.000000
# 36        Цифровое ПСР-Предприятие (Lean Smart Plant)   24  106.000000
# 37                                      Электромонтаж   16  100.000000
# 38                                        Электроника   19  100.000000
#
#      Баллы, %  cnt_users  cluster
# 0   52.620000          1        0
# 1   44.152000          2        1
# 2   69.104000          2        4
# 3   51.631333          2        1
# 4   67.777500          3        4
# 5   62.883333          2        4
# 6   29.062222          1        0
# 7   31.878000          2        1
# 8   51.706667          1        0
# 9   70.763750          2        4
# 10  47.405000          4        2
# 11   8.328000          2        3
# 12  27.521429          2        1
# 13  53.938750          2        1
# 14  42.183333          2        1
# 15  40.536364          2        1
# 16  53.960000          2        1
# 17  63.912500          1        0
# 18  46.901667          2        1
# 19  46.490000          2        1
# 20  44.642222          3        1
# 21  36.252000          2        1
# 22  47.405000          2        1
# 23  48.974286          1        0
# 24  44.000000          1        0
# 25  59.136667          2        4
# 26  40.381500          2        1
# 27  30.349286          3        1
# 28  47.942857          2        1
# 29  61.562500          2        4
# 30  65.276250          2        4
# 31  47.405000          2        1
# 32  54.240000          1        0
# 33  53.966667          4        2
# 34  42.038571          3        1
# 35  41.534286          1        0
# 36  58.466250          2        4
# 37  41.606875          2        1
# 38  37.719474          2        1

# %%
concated_full_competition_data_grouped.to_csv(r"C:\Users\sahab\Desktop\rijulya_ya_tebya_lublyu.csv")

# %%
new_users
# Out:
#            0         1         2         3         4   5   \
# 0   -0.536056 -1.185890 -0.198545  1.491070  0.632407   0
# 1    1.865476  0.816417 -0.150662  1.312651  0.293599   1
# 2   -0.536056  1.483853 -0.715685  0.598977  0.293599   0
# 3   -0.536056  0.816417 -1.242402 -1.096000  0.293599   0
# 4   -0.536056  0.816417  0.519705 -1.274419  0.293599   0
# ..        ...       ...       ...       ...       ...  ..
# 443  1.865476 -1.185890  0.433515 -0.649954 -1.287508   1
# 444 -0.536056  0.816417  1.055999 -0.293116  0.293599   0
# 445  1.865476  0.816417  1.688059 -1.631256  0.293599   1
# 446 -0.536056  0.816417 -1.395628  1.134233  0.293599   0
# 447 -0.536056  1.483853  0.969809 -1.185209  0.293599   0
#
#                        6                                              7   \
# 0    Участник мероприятия  Цифровое ПСР-Предприятие (Lean Smart Plant);
# 1    Участник мероприятия                         Управление качеством;
# 2    Участник мероприятия                         Сварочные технологии;
# 3    Участник мероприятия                          Инженер-конструктор;
# 4    Участник мероприятия                                     Геодезия;
# ..                    ...                                            ...
# 443  Участник мероприятия                         Квантовые технологии;
# 444  Участник мероприятия                       Неразрушающий контроль;
# 445  Участник мероприятия                       Аналитический контроль;
# 446  Участник мероприятия             Токарные работы на станках с ЧПУ;
# 447  Участник мероприятия                      Изготовление прототипов;
#
#                                                     8   \
# 0                       АО Чепецкий механический завод
# 1    Акционерное общество  Научно-исследовательский...
# 2    "Филиал Акционерного общества ""Русатом Инфрас...
# 3    "Акционерное Общество ""Машиностроительный зав...
# 4                     ОБПОУ Курский монтажный техникум
# ..                                                 ...
# 443  Национальный Исследовательский Томский Государ...
# 444                             Управление предприятия
# 445   Центральная научно-исследовательская лаборатория
# 446  "АО ""Опытное Конструкторское Бюро Машинострое...
# 447  Технологический Институт Национальный Исследов...
#
#                                               9                        10
# 0    Цифровое ПСР-Предприятие (Lean Smart Plant)  Промышленная автоматика
# 1                           Управление качеством                      NaN
# 2                           Сварочные технологии                      NaN
# 3                            Инженер-конструктор                      NaN
# 4                                       Геодезия                      NaN
# ..                                           ...                      ...
# 443                         Квантовые технологии                      NaN
# 444                       Неразрушающий контроль   Неразрушающий контроль
# 445                       Аналитический контроль                      NaN
# 446             Токарные работы на станках с ЧПУ                      NaN
# 447                      Изготовление прототипов                      NaN
#
# [448 rows x 11 columns]

# %%
new_data["IT"] = np.random.uniform(0, 1, len(new_data))
new_data["Физика"] = np.random.uniform(0, 1, len(new_data))
new_data["Гуманитарные науки"] = np.random.uniform(0, 1, len(new_data))
new_data["Строительство"] = np.random.uniform(0, 1, len(new_data))
new_data["Электроника"] = np.random.uniform(0, 1, len(new_data))

# %%
new_data.to_csv(r"C:\Users\sahab\Desktop\csv\new_us_dec_data.csv")

# %%
new_data
# Out:
#           Пол  Категория  Место работы  Компетенция  Баллы, ед.  clusters  \
# 0   -0.536056  -1.185890     -0.198545     1.491070    0.632407         1
# 1    1.865476   0.816417     -0.150662     1.312651    0.293599         0
# 2   -0.536056   1.483853     -0.715685     0.598977    0.293599         3
# 3   -0.536056   0.816417     -1.242402    -1.096000    0.293599         0
# 4   -0.536056   0.816417      0.519705    -1.274419    0.293599         0
# ..        ...        ...           ...          ...         ...       ...
# 443  1.865476  -1.185890      0.433515    -0.649954   -1.287508         1
# 444 -0.536056   0.816417      1.055999    -0.293116    0.293599         0
# 445  1.865476   0.816417      1.688059    -1.631256    0.293599         0
# 446 -0.536056   0.816417     -1.395628     1.134233    0.293599         0
# 447 -0.536056   1.483853      0.969809    -1.185209    0.293599         3
#
#       family  Пол_dec Роль в мероприятии_dec  \
# 0      ФИО_0        0   Участник мероприятия
# 1      ФИО_1        1   Участник мероприятия
# 2      ФИО_2        0   Участник мероприятия
# 3      ФИО_3        0   Участник мероприятия
# 4      ФИО_4        0   Участник мероприятия
# ..       ...      ...                    ...
# 443  ФИО_443        1   Участник мероприятия
# 444  ФИО_444        0   Участник мероприятия
# 445  ФИО_445        1   Участник мероприятия
# 446  ФИО_446        0   Участник мероприятия
# 447  ФИО_447        0   Участник мероприятия
#
#                             Список компетенций_dec  \
# 0    Цифровое ПСР-Предприятие (Lean Smart Plant);
# 1                           Управление качеством;
# 2                           Сварочные технологии;
# 3                            Инженер-конструктор;
# 4                                       Геодезия;
# ..                                             ...
# 443                         Квантовые технологии;
# 444                       Неразрушающий контроль;
# 445                       Аналитический контроль;
# 446             Токарные работы на станках с ЧПУ;
# 447                      Изготовление прототипов;
#
#                                       Место работы_dec  \
# 0                       АО Чепецкий механический завод
# 1    Акционерное общество  Научно-исследовательский...
# 2    "Филиал Акционерного общества ""Русатом Инфрас...
# 3    "Акционерное Общество ""Машиностроительный зав...
# 4                     ОБПОУ Курский монтажный техникум
# ..                                                 ...
# 443  Национальный Исследовательский Томский Государ...
# 444                             Управление предприятия
# 445   Центральная научно-исследовательская лаборатория
# 446  "АО ""Опытное Конструкторское Бюро Машинострое...
# 447  Технологический Институт Национальный Исследов...
#
#                                  Компетенция_dec            Профессия_dec  \
# 0    Цифровое ПСР-Предприятие (Lean Smart Plant)  Промышленная автоматика
# 1                           Управление качеством                      NaN
# 2                           Сварочные технологии                      NaN
# 3                            Инженер-конструктор                      NaN
# 4                                       Геодезия                      NaN
# ..                                           ...                      ...
# 443                         Квантовые технологии                      NaN
# 444                       Неразрушающий контроль   Неразрушающий контроль
# 445                       Аналитический контроль                      NaN
# 446             Токарные работы на станках с ЧПУ                      NaN
# 447                      Изготовление прототипов                      NaN
#
#            IT    Физика  Гуманитарные науки  Строительство  Электроника
# 0    0.616905  0.884410            0.192416       0.210817     0.915777
# 1    0.497596  0.634175            0.752185       0.606657     0.316765
# 2    0.497672  0.644937            0.224431       0.083128     0.736934
# 3    0.249340  0.346129            0.300306       0.029432     0.217055
# 4    0.318091  0.726605            0.420462       0.080049     0.917734
# ..        ...       ...                 ...            ...          ...
# 443  0.062286  0.519659            0.841695       0.013828     0.652816
# 444  0.540321  0.040128            0.820170       0.929689     0.044121
# 445  0.209812  0.303664            0.029882       0.152384     0.123152
# 446  0.263090  0.139302            0.603883       0.200480     0.832563
# 447  0.419030  0.787117            0.257786       0.545624     0.060461
#
# [448 rows x 18 columns]
